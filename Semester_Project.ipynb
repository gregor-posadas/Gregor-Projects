# %% [markdown]
# <a href="https://colab.research.google.com/github/gregor-posadas/Gregor-Projects/blob/main/Semester_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **A Metro Manila Flood-Risk Assessment Model Combining Both Waternet and Open Buildings Datasets**

# %% [markdown]
# # **Introduction**
# Metro Manila is the name given to the Philippines' capial region as well as its largest metropolitan area. The region itself consists of sixteen (16) incredibly urbanized and highly populated cities. It includes Manila, Caloocan, Las Pinas, Makati, Malabon, Mandaluyong, Marikina, Muntinlupa, Navotas, Paranaque, Pasay, Pasig, Quezon City, San Juan, Taguig, and Valenzuela. Collectively, these cities suffer tremendously during extreme weather events. Flooding, in particular, poses the biggest risk to both infrastructure and human life to this region.
#
# According to the Philippine Statistics Authority (PSA), between 100,000 and 120,000 homes were partially damaged due to major disasters in the Philippines. Major disasters include earthquakes, low pressure areas, northeast monsoons, shearlines, and tropical cyclones. In October 2024, 150 people were either dead or missing during the onslaught of Tropical Storm Trami in just a single municipality in the province of Batangas. Imagine the risk to infrastructure and the public if such disasters hit somewhere more urbanized and densely populated.
#
# The challenge brought by such natural disasters - flooding in particular - to both infrastructure and human life calls for an assessment of the country's major population centers as well as an overall risk assessment of these areas when it comes to major hydrological events.
#
# Fortunately, recent advancements in Artificial Intelligence (AI) have provided us with datasets that previously would have taken several years to quantify. Two such datasets that may prove useful in a proposed risk assessment of the Philippines' metropolitan areas are the Waternet dataset and Google Research's Open Buildings dataset. Waternet is a result of a collaboration between Bridges to Prosperity (B2P) and the Better Planet Laboratory. This dataset triples the known extent of mapped waterways globally and was generated by the Waternet AI model. The Open Buildings dataset contains 1.8 billion building detections across 58 million square kilometers in the Global South.
#
# Incorporating both of these datasets into a computational model could help Philippine planners and policymakers understand the vulnerability of the country's major ubran areas to flooding and extreme hydrological events. In addition, incorporating open access datasets such as Giologicx's AEGIS Dataset (a.k.a. Metro Manila Flood Landscape Data) could help give the model more robustness in simulating flood elevations in these urbanized areas.

# %% [markdown]
# # **Model Description**
#
# Flooding remains a critical challenge for Metro Manila, where rapid urbanization, inadequate drainage systems, and increasing climate variability converge to amplify the impact of extreme hydrological events. This model aims to integrate state-of-the-art geospatial datasets with computational tools to assess the region’s resilience to flooding. By combining hydrological data, building information, and flood elevation data, the model provides a comprehensive understanding of the interplay between natural and built environments during flood events.
#
# The model integrates three key datasets:
#
# * **Waternet**: An AI-powered dataset that expands the known extent of global waterways, including previously unmapped streams and rivers. For Metro Manila, Waternet provides a highly detailed mapping of water flow pathways that are critical for understanding hydrodynamic behavior.
#
# * **Open Buildings Dataset**: A high-resolution dataset of building footprints, including their structural characteristics and usage types (e.g., residential, commercial). This enables the model to assess the vulnerability of critical infrastructure to flooding.
#
# * **Metro Manila Flood Landscape Data (AEGIS Dataset)**: This dataset contains flood elevation data for various locations in Metro Manila. It provides crucial information about inundation depths under different flood scenarios, allowing for more accurate modeling of flood impacts on urban areas. This is honestly not the most robust dataset when it comes to flood depths in Metro Manila, though it is derived from raw data from the Philippines' Project NOAH (Nationwide Operational Assessment of Hazards).
#
# The proposed model would consist of the following key processes:
#
# * **Hydrodynamic Simulation**: Using the Waternet dataset, the model simulates water flow dynamics during extreme rainfall events, identifying areas where water accumulates and floods.
#
# * **Flood Elevation Analysis**: The AEGIS Dataset enables the model to incorporate real-world flood elevation data, refining predictions of inundation levels and the spatial extent of flooding.
#
# * **Urban Vulnerability Assessment**: The Open Buildings dataset is used to assess the exposure of built infrastructure to flooding. Vulnerability metrics are calculated based on building density, type, and proximity to water flow paths.
#
# * **Resilience Scoring**: Outputs from the hydrodynamic, elevation, and vulnerability analyses are combined to assign resilience scores to different areas within Metro Manila, highlighting priority zones for intervention.
#
# Traditional flood models like HEC-RAS and SWMM have been widely applied for urban flood studies. While effective, these models often rely on static datasets and lack the granularity required for detailed urban analysis. By incorporating dynamic AI-powered datasets and flood elevation data, this model offers significant advancements in predictive accuracy and spatial resolution.
#
# **Conceptual Diagram**
# ![Screenshot 2024-12-12 145502.png](data:image/png;base64,...)
# *Fig 1. Metro Manila Flood-Risk Assessment Model Conceptual Diagram*
#
# The diagram lays out how our Flood Risk Assessment Model works for Metro Manila, Philippines. It all starts with three main data sources: the Waternet Dataset gives us detailed info about the region's waterways, the Open Buildings Dataset maps out where all the buildings are and how dense the areas are, and Giologicx's AEGIS Dataset provides specialized flood elevation and position data for the region. On top of that, we factor in initial conditions like the current water levels and the state of infrastructure, along with parameters such as how intense rainfall can get and how effective the drainage systems are. We also set some boundary conditions to define the geographic limits of Metro Manila and the time frame we're looking at for potential flood events.
#
# All this info flows into the data integration stage, where we mash everything together into one big, unified database. Next up is data preprocessing, where we clean up the data, make sure everything lines up spatially, and get it ready for analysis. After that, we move to feature extraction, picking out the key details like how close areas are to waterways, building densities, elevation levels, and any historical flood data we have.
#
# With the features ready, we dive into the aacutal modeling and analysis part, which has two main pieces: Flood Simulation and Risk Assessment. The flood simulation uses hydrodynamic models to predict what different flood scenarios might look like based on various weather events. Then, the risk assessment takes those simulations and figures out which parts of Metro Manila are most at risk, looking at things like how deep the water could get and which buildings and infrastructure might be affected.
#
# Finally, the model spits out outputs in the form of flood risk maps and risk reports. The Flood Risk Maps visually show the high-risk areas and potential flood zones, which are super handy for planning and emergency response. The Risk Reports break down all the data and analyses, offering insights and recommendations for how to better prepare and protect the city from future floods. This whole setup helps Metro Manila's planners and decision-makers get a clear picture of flood risks and take informed steps to boost the city's resilience against major water events.

# %% [markdown]
# # **Data Needs**
# To effectively assess flood risks in Metro Manila, the proposed model would rely on a mix of data types that capture the area's unique urban and hydrological features.
#
# **Input Data**
#
# * Historical and real-time rainfall data from the Philippine Atmospheric, Geophysical and Astronomical Services Administration (PAGASA) to model different storm scenarios and understand how varying precipitation levels affect flooding.
#
# * Detailed maps of rivers, canals, and drainage systems from the Waternet Dataset help us track water flow and identify potential flood paths.
#
# * Building Footprints from the Open Buildings Dataset can provide precise locations and types of buildings across Metro Manila. This info is crucial for assessing which structures are most at risk during floods.
#
# * Data from the Philippine Statistics Authority (PSA) can help us pinpoint densely populated areas, so we can evaluate the human impact of potential floods.
#
# * Information on key facilities like hospitals, schools, and transportation hubs ensures we can prioritize protection efforts where they’re needed most.
#
# **Output Data**
#
# * GIS-compatible files that visually highlight flood-prone areas, making it easy to integrate with mapping tools for planning and response.
# Risk Reports
#
# * PDF reports/documents and interactive dashboards that summarize flood risks, highlight vulnerable infrastructure, and provide actionable recommendations for mitigation and planning.
#
# Something important to note is that before feeding the data into our model, we’ll need to do some preprocessing steps since we're combining a bunch of data. We will need to make sure all spatial data uses the same coordinate system for accurate layering and analysis. We will also need to remove any inconsistencies, fill in missing values, and standardize units across different datasets to ensure everything works smoothly together.
#
# Prehaps the biggest thing we will have to focus on is getting key details like building density, elevation levels, and proximity to waterways, which are essential for accurate flood simulations.
#
# **Data Sources**
#
# * Waternet Dataset: Available through Bridges to Prosperity’s data portal.
#
# * Open Buildings Dataset: Accessible via Google Research’s open data platforms.
#
# * AEGIS Dataset: Obtainable from Giologicx’s official channel on Kaggle.
#
# * Rainfall Data: Sourced from PAGASA and the National Aeronautics and Space Administration's (NASA) data repositories.

# %% [markdown]
# # **Calibration**
#
# Calibrating our flood risk assessment model is essential to ensure its predictions are accurate and reliable for Metro Manila. Calibration involves fine-tuning key variables and parameters so that the model's outputs align closely with real-world observations.
#
# Below are some key parameters we need to calibrate our
# hydrological parameters:
#
# * **Manning’s Roughness Coefficient**: This determines how much resistance water faces as it flows through different types of surfaces. Adjusting this helps simulate realistic water speeds and depths.
#
# * **Inflow Rates**: These are the amounts of water entering the system from rainfall and upstream sources. Calibrating inflow rates ensures our simulations match actual storm events.
#
# * **Water Surface Elevation**: Fine-tuning the starting water levels based on historical flood data helps us predict accurate inundation areas.
#
# * **Runoff Coefficients**: These indicate how much rainfall turns into surface runoff versus soaking into the ground. Adjusting these helps model how quickly areas can flood.
#
# * **Building Resistance Factors**: These factors assess how different types of buildings withstand floodwaters. Calibrating them ensures our vulnerability assessments are spot on.
#
# * **Drainage Capacity**: This determines how effectively the city’s drainage systems can handle excess water. Adjusting this parameter helps simulate potential drainage failures during extreme events.
#
# Once we have all that figured out, we will need to compare the model to real life data. We can use maps and records from past flood events in Metro Manila to see if our model accurately predicts where and how much flooding occurred.
# We can also use data from monitoring stations across Metro Manila which will help us verify if our simulated water levels match real observations during storms. Additionally, before-and-after satellite images from events like Tropical Storm Trami will help us visually assess the accuracy of our flood maps.
#
# In a study conducted in Jakarta (Pratiwi et al., 2024), researchers compared the Geomorphic Flood Index (GFI) method with the HEC-RAS hydraulic model. They utilized historical flood data from the February 2017 event to evaluate the accuracy of both models. By comparing the model predictions with actual flood extents and water levels, they adjusted inflow rates and flood surface elevations to improve the HEC-RAS model’s accuracy. The study found that the HEC-RAS model’s predictions closely matched the real flood data, whereas the GFI method tended to overestimate inundation areas. This highlights the importance of using real-world data to calibrate flood models, ensuring their reliability for urban flood management.

# %% [markdown]
# # **Numerical Design Experiment**
#
# To address the persistent flood challenges faced by Metro Manila, the numerical experiment is designed to test how well the flood risk assessment model can predict and mitigate flood impacts under various scenarios. In general terms, we start with a hypothesis that the model, which combines advanced geospatial datasets with hydrodynamic simulations, will accurately identify high-risk flood zones and provide actionable insights for urban planners and policymakers. To put this to the test, we can have the model simulate a range of flood events using both historical rainfall data and projected climate scenarios. By inputting these different rainfall intensities and durations into the model, we can observe how water flows through the intricate network of waterways mapped by the Waternet Dataset and how it interacts with the densely built environment captured by the Open Buildings Dataset.
#
# Step one of the experiment involves calibrating our model using data from past flood events. Ideally, it would be good to have access to actual flood data for Metro Manila from meteorological organizations in the Philippines (this often involves reaching out directly to certain agencies as most data about this topic isn't open access). By comparing the model’s predictions with the actual flood extents and water levels recorded during these events, we can fine-tune parameters like inflow rates and drainage capacities to enhance the model’s accuracy. Once calibrated, the model will be used to run simulations of future flood scenarios, incorporating factors like increased rainfall intensity due to climate change and potential improvements in drainage infrastructure.
#
# A key part of the experiment is to evaluate different flood mitigation strategies within the model. For instance, we can simulate the impact of expanding drainage systems or implementing green infrastructure solutions such as permeable pavements and urban green spaces. By comparing the outcomes of these scenarios, we can identify which strategies most effectively reduce flood risks and enhance the resilience of Metro Manila’s urban landscape. This not only provides practical recommendations for flood management but also demonstrates the model’s utility in supporting evidence-based decision-making.
#
# Additionally, the experiment can potentially extend previous studies by using real-time data feeds and leveraging AI-powered datasets, which offer a more detailed understanding of urban flood dynamics compared to traditional models like HEC-RAS and SWMM. This allows us to capture the complexities of Metro Manila’s rapid urbanization and changing climate patterns more accurately. By conducting this numerical experiment, we can validate our model’s predictions, refine its parameters, and ultimately provide a robust tool that can help mitigate the devastating impacts of future floods in Metro Manila. The results of these simulations will be visualized through flood risk maps and detailed reports.
#
# In summary, the numerical experiment aims to validate and enhance our flood risk assessment model, ensuring it not only reflects the current flood dynamics of Metro Manila but also provides forward-looking solutions for the city’s resilience against future hydrological threats.

# %% [markdown]
# # **References**
# Associated Press. (2024, October 28). Philippines flood landslide. OPB. https://www.opb.org/article/2024/10/28/philippines-flood-landslide/
#
# Giologicx. (n.d.). AEGIS Dataset [Data set]. Kaggle. https://www.kaggle.com/datasets/giologicx/aegisdataset
#
# Kruse, C. (2023, May 15). Waternet: AI-powered global water mapping triples known waterways. Medium. https://medium.com/fika-blog/waternet-ai-powered-global-water-mapping-triples-known-waterways-bc3095783661
#
# Pratiwi, A. P., Rohmat, F. I. W., Nugroho, E. O., Farid, M., & Kusuma, M. S. B. (2024). Flood hazard comparison based on geomorphic flood index and hydraulic HEC-RAS (Case study in Ciliwung Watershed, Jakarta). In The 2nd International Conference on Disaster Management and Climate Change 2023. IOP Conference Series: Earth and Environmental Science, 1314, 012084. https://doi.org/10.1088/1755-1315/1314/1/012084
#
# Philippine Statistics Authority. (2022). CPES 2012-2022 [Data set]. Philippine Statistics Authority. https://library.psa.gov.ph/kohaimages/PSA/ebookreader/viewebook.html?out=1&d=pdf/131cb610d659131c628a938dea5ca8bc_CPES%202012-2022%20final_signed.pdf&speech=1&ref=https://library.psa.gov.ph/cgi-bin/koha/opac-detail.pl?biblionumber=25685&biblionumber=25685#book/487
#
# Philippine Statistics Authority. (n.d.). Component 4: Extreme events and disaster. Philippine Statistics Authority. https://psa.gov.ph/statistics/environment-statistics/highlights/component-4-extreme-events-and-disaster
#
# Google Research. (n.d.). Open Buildings. Google Research. https://sites.research.google/gr/open-buildings/
